# %% [markdown]
# # Image Variations Using the API

# %%
import requests
import json
import sys
from openai import OpenAI
import openai
import os

# Get openai key
# Use current working directory and go one level up
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

# Now you can import your config
from config import api_key

client = OpenAI(api_key=api_key)

# %% [raw]
# # A recommended way to store the key is in an environment variable. For this demo, I am storing in a file.
# key_location = '/Users/xavier/github/xmorera/ps-generative-ai-developing-applications-python-openai/key/genaikey.txt'
#
# with open(key_location, 'r') as file:
#     key = file.readline().strip()

# %%
URL = "https://api.openai.com/v1/images/variations"

headers = {
    'Authorization': f'Bearer {api_key}'
}
files = {
    "image": open("./otter1.png", "rb")
}
data = {
    "n": 2,
    "size": "1024x1024"
}

response = requests.post(URL, headers=headers, files=files, data=data, timeout=20)

if response.status_code == 200:
    result = response.json()
    print(json.dumps(result, indent=2))
else:
    print('Request failed with status code:', response.status_code)
# Out:
# {
#   "created": 1751828505,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-06TbjnMmqCxUuiUIunjkEDty/user-ZK5TFpY8qfVBMDkxFY3NUpm9/img-QwnhfgohP8ooY4DEo3mOM7fw.png?st=2025-07-06T18%3A01%3A45Z&se=2025-07-06T20%3A01%3A45Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-07-06T14%3A01%3A56Z&ske=2025-07-07T14%3A01%3A56Z&sks=b&skv=2024-08-04&sig=r2okoIH3meW/4yn8FGFL8FSbPvKWhwFKHCP3t%2BpFNPk%3D"
#     },
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-06TbjnMmqCxUuiUIunjkEDty/user-ZK5TFpY8qfVBMDkxFY3NUpm9/img-0A0qCLlg2B9oTbv9XnQ3aDbQ.png?st=2025-07-06T18%3A01%3A45Z&se=2025-07-06T20%3A01%3A45Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-07-06T14%3A01%3A56Z&ske=2025-07-07T14%3A01%3A56Z&sks=b&skv=2024-08-04&sig=sbGzF2%2BOMEPYIij8O1%2ByjczKeqX5bb7h8pZ9OB/darc%3D"
#     }
#   ]
# }
