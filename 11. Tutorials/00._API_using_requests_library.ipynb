# %% [markdown]
# # Using the OpenAI API
# https://platform.openai.com/docs/api-reference/making-requests

# %%
import os
import requests
import json
import sys

# Get openai key
# Use current working directory and go one level up
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

# Now you can import your config
from config import api_key

# %%
prompt = "To succeed in life"

# %%
# Set the endpoint for GPT-3.5 chat completions
endpoint = "https://api.openai.com/v1/chat/completions" 

# Look out for deprecations
# endpoint = "https://api.openai.com/v1/engines/gpt-3.5-turbo-instruct/completions"

# %%
# Set the headers (include your API key for authentication)
headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {api_key}"
}

# %%
# Set the parameters

max_tokens = 50

# Construct the request payload
payload = {
    "model": "gpt-3.5-turbo",
    "messages": [{"role": "user", "content": prompt}],
    "max_tokens": max_tokens
}

# %%
# Make the API request
response = requests.post(endpoint, headers=headers, json=payload)

# %%
# Extract the generated completion from the API response
completion_text = response.json()["choices"][0]["message"]["content"].strip()

# %%
# Print the generated completion
print("Generated completion for prompt '" + prompt + "'\n" + completion_text)
# Out:
# Generated completion for prompt 'To succeed in life'
# , one must have a clear vision of their goals and be willing to work hard to achieve them. It is important to stay focused, determined, and resilient in the face of challenges and setbacks. Developing a strong work ethic, staying organized, and hon

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "id": "chatcmpl-Bp8S73GN0Infk06VHfVelexgWq9fp",
#   "object": "chat.completion",
#   "created": 1751526919,
#   "model": "gpt-3.5-turbo-0125",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": ", one must have a clear vision of their goals and be willing to work hard to achieve them. It is important to stay focused, determined, and resilient in the face of challenges and setbacks. Developing a strong work ethic, staying organized, and hon",
#         "refusal": null,
#         "annotations": []
#       },
#       "logprobs": null,
#       "finish_reason": "length"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 11,
#     "completion_tokens": 50,
#     "total_tokens": 61,
#     "prompt_tokens_details": {
#       "cached_tokens": 0,
#       "audio_tokens": 0
#     },
#     "completion_tokens_details": {
#       "reasoning_tokens": 0,
#       "audio_tokens": 0,
#       "accepted_prediction_tokens": 0,
#       "rejected_prediction_tokens": 0
#     }
#   },
#   "service_tier": "default",
#   "system_fingerprint": null
# }
