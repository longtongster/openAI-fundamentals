# %% [markdown]
# # Image Variations with the Library

# %%
import requests
import json
import sys
from openai import OpenAI
import openai
import os

# Get openai key
# Use current working directory and go one level up
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

# Now you can import your config
from config import api_key

client = OpenAI(api_key=api_key)

# %% [raw]
# # A recommended way to store the key is in an environment variable. For this demo, I am storing in a file.
# key_location = '/Users/xavier/github/xmorera/ps-generative-ai-developing-applications-python-openai/key/genaikey.txt'
#
# with open(key_location, 'r') as file:
#     key = file.readline().strip()

# %%
library_response = client.images.create_variation(
  image=open("./otter1.png", "rb"),
  n=1,
  size="1024x1024"
)

#image_url = library_response['data'][0]['url']
#print(image_url)

# %%
library_response.data[0].url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-06TbjnMmqCxUuiUIunjkEDty/user-ZK5TFpY8qfVBMDkxFY3NUpm9/img-83soH0gba1ttN3ZTRaFLAD1o.png?st=2025-07-06T17%3A59%3A49Z&se=2025-07-06T19%3A59%3A49Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-07-06T08%3A17%3A53Z&ske=2025-07-07T08%3A17%3A53Z&sks=b&skv=2024-08-04&sig=QGkV6nJxOAuGynDrByBx6yZY6cPZk8BNbggV6lx9he8%3D'
