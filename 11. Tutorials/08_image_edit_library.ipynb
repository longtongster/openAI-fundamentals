# %% [markdown]
# # Editing Images with the Library

# %%
import requests
import json
import sys
from openai import OpenAI
import openai
import os

# Get openai key
# Use current working directory and go one level up
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

# Now you can import your config
from config import api_key

client = OpenAI(api_key=api_key)

# %% [raw]
# # A recommended way to store the key is in an environment variable. For this demo, I am storing in a file.
# key_location = '/Users/xavier/github/xmorera/ps-generative-ai-developing-applications-python-openai/key/genaikey.txt'
#
# with open(key_location, 'r') as file:
#     key = file.readline().strip()

# %%
library_response = client.images.edit(
  image=open("./otter1.png", "rb"),
  mask=open("./mask1.png", "rb"),
  prompt="A cute baby sea otter wearing a green beret",
  n=1,
  size="1024x1024"
)

# %%
image_url = library_response.data[0].url
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-06TbjnMmqCxUuiUIunjkEDty/user-ZK5TFpY8qfVBMDkxFY3NUpm9/img-mWDQ8vXXyxkJlFj49o7jVFMv.png?st=2025-07-06T17%3A52%3A53Z&se=2025-07-06T19%3A52%3A53Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=cc612491-d948-4d2e-9821-2683df3719f5&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-07-06T10%3A41%3A46Z&ske=2025-07-07T10%3A41%3A46Z&sks=b&skv=2024-08-04&sig=t8pym1NZ6SZlTaPPIxNT5Lz%2BbFkhT2m9/7OeBAQTu2Y%3D
